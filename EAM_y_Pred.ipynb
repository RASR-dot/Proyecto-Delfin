# %%
import pandas as pd
import numpy as np
import seaborn as sns
    
from sklearn import preprocessing
from matplotlib import pyplot as plt
from scipy.stats import pearsonr
from collections import Counter
from PIL import Image

# %%
def violin(data):
    data.columns = ['Modelo 1', 'Modelo 2', 'Modelo 3', 'Modelo 4']
    sns.despine(offset = 10)
    return sns.violinplot(data = data, scale = 'width', palette = 'Set3')

# %%
errord_1 =  pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Toluca\Toluca\msed15106_1.csv').iloc[:, 1:2]
errord_2 =  pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Toluca\Toluca\msed15106_2.csv').iloc[:, 1:2]
errord_3 =  pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Toluca\Toluca\msed15106_3.csv').iloc[:, 1:2]
errord_4 =  pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Toluca\Toluca\msed15106_4.csv').iloc[:, 1:2]

# %%
errord = pd.concat([errord_1, errord_2, errord_3, errord_4], axis = 1)
errord.columns = ['Modelo 1', 'Modelo 2', 'Modelo 3', 'Modelo 4']
s = np.array(range(1,18))

plt.xticks(np.arange(17), s)
plt.xlabel('Meses del año')
plt.ylabel('Error cuadrático medio')

plt.plot(errord)
plt.legend(['Modelo 1','Modelo 2', 'Modelo 3', 'Modelo 4'])
plt.title('Error cuadrático medio, Municipio 15106 (Toluca)')
plt.draw()
errord
plt.savefig(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Toluca\Toluca\ECM5.png')

# %%
erd_1 =  pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Tlaxcala-Puebla\Puebla\A.csv').iloc[:, 1:8]
erd_2 =  pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Tlaxcala-Puebla\Puebla\B.csv').iloc[:, 1:8]
erd_3 =  pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Tlaxcala-Puebla\Puebla\C.csv').iloc[:, 1:8]
erd_4 =  pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Tlaxcala-Puebla\Puebla\D.csv').iloc[:, 1:8]
erd_5 =  pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\Tlaxcala-Puebla\Puebla\E.csv').iloc[:, 1:8]

# %%
errord = pd.concat([erd_1, erd_2, erd_3, erd_4, erd_5], axis = 0)
errord.columns = ['Modelo 1','Modelo 2', 'Modelo 3', 'Modelo 4', 'Modelo 5', 'Modelo 6', 'Modelo 7']
errord.to_csv('Puebla.csv')

# %%
errord = pd.concat([erd_1, erd_2, erd_3, erd_4, erd_5], axis = 0)
errord.columns = ['Modelo 1','Modelo 2', 'Modelo 3', 'Modelo 4', 'Modelo 5', 'Modelo 6', 'Modelo 7']
errord.drop(errord.iloc[6:7])
pruebas =['Prueba 1','Prueba 2', 'Prueba 3', 'Prueba 4', 'Prueba 5']
errord['Pruebas'] = pruebas

ax = plt.gca()

errord.plot(x = 'Pruebas', y = 'Modelo 1', kind = 'line', ax = ax)
errord.plot(x = 'Pruebas', y = 'Modelo 2', kind = 'line', ax = ax)
errord.plot(x = 'Pruebas', y = 'Modelo 3', kind = 'line', ax = ax)
errord.plot(x = 'Pruebas', y = 'Modelo 4', kind = 'line', ax = ax)
errord.plot(x = 'Pruebas', y = 'Modelo 5', kind = 'line', ax = ax)
errord.plot(x = 'Pruebas', y = 'Modelo 6', kind = 'line', ax= ax)
errord.plot(x = 'Pruebas', y = 'Modelo 7', kind = 'line', ax= ax)

plt.title('Error promedio absoluto, Municipio 15033 (Toluca)')
plt.ylabel('Error promedio absoluto')

plt.savefig(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Errores\México\Ecatepec de Morelos\Prueba5.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-df76886a4333> in <module>
#       1 errord = pd.concat([erd_1, erd_2, erd_3, erd_4, erd_5], axis = 0)
#       2 errord.columns = ['Modelo 1','Modelo 2', 'Modelo 3', 'Modelo 4', 'Modelo 5', 'Modelo 6', 'Modelo 7']
# ----> 3 errord.drop(errord.iloc[6:7])
#       4 pruebas =['Prueba 1','Prueba 2', 'Prueba 3', 'Prueba 4', 'Prueba 5']
#       5 errord['Pruebas'] = pruebas
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
# ...

# %%
a = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\Puebla.csv')
b = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\Toluca.csv')
c = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\Monterrey.csv')
d = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\Ecatepec.csv')
e = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\GDL.csv')

from IPython.display import display_html
def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

display_side_by_side(a, b, c, d ,e )

# %%
Pr09005 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr09005.csv').iloc[:, 1:6]
Pr09007 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr09007.csv').iloc[:, 1:6]
Pr14097 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr14097.csv').iloc[:, 1:6]
Pr14098 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr14098.csv').iloc[:, 1:6]
Pr14101 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr14101.csv').iloc[:, 1:6]
Pr14120 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr14120.csv').iloc[:, 1:6]
Pr15005 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr15005.csv').iloc[:, 1:6]
Pr15033 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr15033.csv').iloc[:, 1:6]
Pr15051 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr15051.csv').iloc[:, 1:6]
Pr15054 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr15054.csv').iloc[:, 1:6]
Pr15058 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr15058.csv').iloc[:, 1:6]
Pr15106 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr15106.csv').iloc[:, 1:6]
Pr15118 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr15118.csv').iloc[:, 1:6]
Pr19019 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr19019.csv').iloc[:, 1:6]
Pr19026 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr19026.csv').iloc[:, 1:6]
Pr19039 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr19039.csv').iloc[:, 1:6]
Pr19046 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr19046.csv').iloc[:, 1:6]
Pr19049 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr19049.csv').iloc[:, 1:6]
Pr21015 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr21015.csv').iloc[:, 1:6]
Pr21041 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr21041.csv').iloc[:, 1:6]
Pr21114 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr21114.csv').iloc[:, 1:6]
Pr21119 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr21119.csv').iloc[:, 1:6]
Pr21132 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr21132.csv').iloc[:, 1:6]
Pr21140 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\Pr21140.csv').iloc[:, 1:6]
Pr14039 = pd.read_csv(r'C:\Users\D-Shield\Documents\Proyecto Delfín\Datos violencia\2020\DelitosMun\Predicciones\PrGDL.csv').iloc[:, 1:6]

# %%
Mayo = pd.concat([pred3(Pr09005, '9005').iloc[4:5, :], pred3(Pr09007, '9007').iloc[4:5, :], pred3(Pr14097, '14097').iloc[4:5, :], 
           pred3(Pr14098, '14098').iloc[4:5, :], pred3(Pr14101, '14101').iloc[4:5, :], pred3(Pr14039, '14039').iloc[4:5, :],
           pred3(Pr14120, '14120').iloc[4:5, :], pred3(Pr15005, '15005').iloc[4:5, :], pred3(Pr15033, '15033').iloc[4:5, :],
           pred3(Pr15051, '15051').iloc[4:5, :], pred3(Pr15054, '15054').iloc[4:5, :], pred3(Pr15058, '15058').iloc[4:5, :],
           pred3(Pr15106, '15106').iloc[4:5, :], pred3(Pr15118, '15118').iloc[4:5, :], pred3(Pr19019, '19019').iloc[4:5, :],
           pred3(Pr19026, '19026').iloc[4:5, :], pred3(Pr19039, '19039').iloc[4:5, :], pred3(Pr19046, '19046').iloc[4:5, :], 
           pred3(Pr19049, '19049').iloc[4:5, :], pred3(Pr21015, '21015').iloc[4:5, :], pred3(Pr21041, '21041').iloc[4:5, :],
           pred3(Pr21114, '21114').iloc[4:5, :], pred3(Pr21119, '21119').iloc[4:5, :], pred3(Pr21132, '21132').iloc[4:5, :],
           pred3(Pr21140, '21140').iloc[4:5, :]])

Mayo.to_csv('Mayo3.csv')

# %%
def real(data, cl):
    y = ['Real', 'Predicción 1', 'Predicción 2', 'Predicción 3']
    z = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
    data.index = z
    data.columns = y
    cl_mun = [cl, cl, cl, cl, cl]
    idx = 0   
    data.insert(loc = idx, column = 'Clave municipal', value = cl_mun)
    return data[['Clave municipal', 'Real']]

def pred1(data, cl):
    y = ['Real', 'Predicción 1', 'Predicción 2', 'Predicción 3']
    z = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
    data.index = z
    data.columns = y
    cl_mun = [cl, cl, cl, cl, cl]
    idx = 0   
    data.insert(loc = idx, column = 'Clave municipal', value = cl_mun)
    return data[['Clave municipal', 'Predicción 1']]


def pred2(data, cl):
    y = ['Real', 'Predicción 1', 'Predicción 2', 'Predicción 3']
    z = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
    data.index = z
    data.columns = y
    cl_mun = [cl, cl, cl, cl, cl]
    idx = 0   
    data.insert(loc = idx, column = 'Clave municipal', value = cl_mun)
    return data[['Clave municipal', 'Predicción 2']]

def pred3(data, cl):
    y = ['Real', 'Predicción 1', 'Predicción 2', 'Predicción 3']
    z = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
    data.index = z
    data.columns = y
    cl_mun = [cl, cl, cl, cl, cl]
    idx = 0   
    data.insert(loc = idx, column = 'Clave municipal', value = cl_mun)
    return data[['Clave municipal', 'Predicción 3']]

# %%
Enero = pd.concat([pred1(Pr09005, '9005').iloc[0:1, :], pred1(Pr09007, '9007').iloc[0:1, :], pred1(Pr14097, '14097').iloc[0:1, :], 
           pred1(Pr14098, '14098').iloc[0:1, :], pred1(Pr14101, '14101').iloc[0:1, :], pred1(Pr14039, '14039').iloc[0:1, :],
           pred1(Pr14120, '14120').iloc[0:1, :], pred1(Pr15005, '15005').iloc[0:1, :], pred1(Pr15033, '15033').iloc[0:1, :],
           pred1(Pr15051, '15051').iloc[0:1, :], pred1(Pr15054, '15054').iloc[0:1, :], pred1(Pr15058, '15058').iloc[0:1, :],
           pred1(Pr15106, '15106').iloc[0:1, :], pred1(Pr15118, '15118').iloc[0:1, :], pred1(Pr19019, '19019').iloc[0:1, :],
           pred1(Pr19026, '19026').iloc[0:1, :], pred1(Pr19039, '19039').iloc[0:1, :], pred1(Pr19046, '19046').iloc[0:1, :], 
           pred1(Pr19049, '19049').iloc[0:1, :], pred1(Pr21015, '21015').iloc[0:1, :], pred1(Pr21041, '21041').iloc[0:1, :],
           pred1(Pr21114, '21114').iloc[0:1, :], pred1(Pr21119, '21119').iloc[0:1, :], pred1(Pr21132, '21132').iloc[0:1, :],
           pred1(Pr21140, '21140').iloc[0:1, :]])

Enero.to_csv('Enero.csv')

Febrero = pd.concat([pred1(Pr09005, '9005').iloc[1:2, :], pred1(Pr09007, '9007').iloc[1:2, :], pred1(Pr14097, '14097').iloc[1:2, :], 
           pred1(Pr14098, '14098').iloc[1:2, :], pred1(Pr14101, '14101').iloc[1:2, :], pred1(Pr14039, '14039').iloc[1:2, :],
           pred1(Pr14120, '14120').iloc[1:2, :], pred1(Pr15005, '15005').iloc[1:2, :], pred1(Pr15033, '15033').iloc[1:2, :],
           pred1(Pr15051, '15051').iloc[1:2, :], pred1(Pr15054, '15054').iloc[1:2, :], pred1(Pr15058, '15058').iloc[1:2, :],
           pred1(Pr15106, '15106').iloc[1:2, :], pred1(Pr15118, '15118').iloc[1:2, :], pred1(Pr19019, '19019').iloc[1:2, :],
           pred1(Pr19026, '19026').iloc[1:2, :], pred1(Pr19039, '19039').iloc[1:2, :], pred1(Pr19046, '19046').iloc[1:2, :], 
           pred1(Pr19049, '19049').iloc[1:2, :], pred1(Pr21015, '21015').iloc[1:2, :], pred1(Pr21041, '21041').iloc[1:2, :],
           pred1(Pr21114, '21114').iloc[1:2, :], pred1(Pr21119, '21119').iloc[1:2, :], pred1(Pr21132, '21132').iloc[1:2, :],
           pred1(Pr21140, '21140').iloc[1:2, :]])

Febrero.to_csv('Febrero.csv')

Marzo = pd.concat([pred1(Pr09005, '9005').iloc[2:3, :], pred1(Pr09007, '9007').iloc[2:3, :], pred1(Pr14097, '14097').iloc[2:3, :], 
           pred1(Pr14098, '14098').iloc[2:3, :], pred1(Pr14101, '14101').iloc[2:3, :], pred1(Pr14039, '14039').iloc[2:3, :],
           pred1(Pr14120, '14120').iloc[2:3, :], pred1(Pr15005, '15005').iloc[2:3, :], pred1(Pr15033, '15033').iloc[2:3, :],
           pred1(Pr15051, '15051').iloc[2:3, :], pred1(Pr15054, '15054').iloc[2:3, :], pred1(Pr15058, '15058').iloc[2:3, :],
           pred1(Pr15106, '15106').iloc[2:3, :], pred1(Pr15118, '15118').iloc[2:3, :], pred1(Pr19019, '19019').iloc[2:3, :],
           pred1(Pr19026, '19026').iloc[2:3, :], pred1(Pr19039, '19039').iloc[2:3, :], pred1(Pr19046, '19046').iloc[2:3, :], 
           pred1(Pr19049, '19049').iloc[2:3, :], pred1(Pr21015, '21015').iloc[2:3, :], pred1(Pr21041, '21041').iloc[2:3, :],
           pred1(Pr21114, '21114').iloc[2:3, :], pred1(Pr21119, '21119').iloc[2:3, :], pred1(Pr21132, '21132').iloc[2:3, :],
           pred1(Pr21140, '21140').iloc[2:3, :]])

Marzo.to_csv('Marzo.csv')

Abril = pd.concat([pred1(Pr09005, '9005').iloc[3:4, :], pred1(Pr09007, '9007').iloc[3:4, :], pred1(Pr14097, '14097').iloc[3:4, :], 
           pred1(Pr14098, '14098').iloc[3:4, :], pred1(Pr14101, '14101').iloc[3:4, :], pred1(Pr14039, '14039').iloc[3:4, :],
           pred1(Pr14120, '14120').iloc[3:4, :], pred1(Pr15005, '15005').iloc[3:4, :], pred1(Pr15033, '15033').iloc[3:4, :],
           pred1(Pr15051, '15051').iloc[3:4, :], pred1(Pr15054, '15054').iloc[3:4, :], pred1(Pr15058, '15058').iloc[3:4, :],
           pred1(Pr15106, '15106').iloc[3:4, :], pred1(Pr15118, '15118').iloc[3:4, :], pred1(Pr19019, '19019').iloc[3:4, :],
           pred1(Pr19026, '19026').iloc[3:4, :], pred1(Pr19039, '19039').iloc[3:4, :], pred1(Pr19046, '19046').iloc[3:4, :], 
           pred1(Pr19049, '19049').iloc[3:4, :], pred1(Pr21015, '21015').iloc[3:4, :], pred1(Pr21041, '21041').iloc[3:4, :],
           pred1(Pr21114, '21114').iloc[3:4, :], pred1(Pr21119, '21119').iloc[3:4, :], pred1(Pr21132, '21132').iloc[3:4, :],
           pred1(Pr21140, '21140').iloc[3:4, :]])

Abril.to_csv('Abril.csv')

Mayo = pd.concat([pred1(Pr09005, '9005').iloc[4:5, :], pred1(Pr09007, '9007').iloc[4:5, :], pred1(Pr14097, '14097').iloc[4:5, :], 
           pred1(Pr14098, '14098').iloc[4:5, :], pred1(Pr14101, '14101').iloc[4:5, :], pred1(Pr14039, '14039').iloc[4:5, :],
           pred1(Pr14120, '14120').iloc[4:5, :], pred1(Pr15005, '15005').iloc[4:5, :], pred1(Pr15033, '15033').iloc[4:5, :],
           pred1(Pr15051, '15051').iloc[4:5, :], pred1(Pr15054, '15054').iloc[4:5, :], pred1(Pr15058, '15058').iloc[4:5, :],
           pred1(Pr15106, '15106').iloc[4:5, :], pred1(Pr15118, '15118').iloc[4:5, :], pred1(Pr19019, '19019').iloc[4:5, :],
           pred1(Pr19026, '19026').iloc[4:5, :], pred1(Pr19039, '19039').iloc[4:5, :], pred1(Pr19046, '19046').iloc[4:5, :], 
           pred1(Pr19049, '19049').iloc[4:5, :], pred1(Pr21015, '21015').iloc[4:5, :], pred1(Pr21041, '21041').iloc[4:5, :],
           pred1(Pr21114, '21114').iloc[4:5, :], pred1(Pr21119, '21119').iloc[4:5, :], pred1(Pr21132, '21132').iloc[4:5, :],
           pred1(Pr21140, '21140').iloc[4:5, :]])

Mayo.to_csv('Mayo.csv')
