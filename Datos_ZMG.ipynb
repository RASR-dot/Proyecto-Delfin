# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\Hp  User\Documents\Delfín\Datos\Municipios2015.csv', encoding = 'utf8')

# %%
Jalisco = data[data.Entidad == 'Jalisco']

# %%
df_15 = Jalisco.loc[Jalisco['Municipio'].isin(['Guadalajara','Zapopan', "San Pedro Tlaquepaque"])]

# %%
delitos = df_15.set_index(['Tipo de delito'])

delitos.drop(delitos.iloc[:, 0:8], inplace = True, axis = 1)

# %%
dfd_15 = delitos.groupby(level=-1, axis=0).sum()

# %%
import matplotlib.pyplot as plt
import pylab as plot
import numpy as np
import calendar 

deli_15 = dfd_15.transpose()

deli_15.plot()
plt.xticks(np.arange(12), dfd_15, rotation=30)
plt.xlabel('Meses del año')
plt.ylabel('Número de delitos')

leg = plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", fontsize = 'small')

# %%
data_16 = pd.read_csv(r'C:\Users\Hp  User\Documents\Delfín\Datos\Municipios2016.csv', encoding = 'utf8')

Jalisco_16 = data_16[data_16.Entidad == 'Jalisco']

df_16 = Jalisco_16.loc[Jalisco_16['Municipio'].isin(['Guadalajara','Zapopan', "San Pedro Tlaquepaque"])]

delitos_16 = df_16.set_index(['Tipo de delito'])

delitos_16.drop(delitos_16.iloc[:, 0:8], inplace = True, axis = 1) 

dfd_16 = delitos_16.groupby(level=-1, axis=0).sum()

deli_16 = dfd_16.transpose()

deli_16.plot()
plt.xticks(np.arange(12), dfd_16, rotation=30)
plt.xlabel('Meses del año')
plt.ylabel('Número de delitos')

leg = plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", fontsize = 'small')

# %%
data_17 = pd.read_csv(r'C:\Users\Hp  User\Documents\Delfín\Datos\Municipios2017.csv', encoding = 'utf8')

Jalisco_17 = data_17[data_17.Entidad == 'Jalisco']

df_17 = Jalisco_17.loc[Jalisco_17['Municipio'].isin(['Guadalajara','Zapopan', "San Pedro Tlaquepaque"])]

delitos_17 = df_17.set_index(['Tipo de delito'])

delitos_17.drop(delitos_17.iloc[:, 0:8], inplace = True, axis = 1) 

dfd_17 = delitos_17.groupby(level=-1, axis=0).sum()

deli_17 = dfd_17.transpose()

deli_17.plot()
plt.xticks(np.arange(12), dfd_17, rotation=30)
plt.xlabel('Meses del año')
plt.ylabel('Número de delitos')

leg = plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", fontsize = 'small')

# %%
data_18 = pd.read_csv(r'C:\Users\Hp  User\Documents\Delfín\Datos\Municipios2018.csv', encoding = 'utf8')

Jalisco_18 = data_18[data_18.Entidad == 'Jalisco']

df_18 = Jalisco_18.loc[Jalisco_18['Municipio'].isin(['Guadalajara','Zapopan', "San Pedro Tlaquepaque"])]

delitos_18 = df_18.set_index(['Tipo de delito'])

delitos_18.drop(delitos_18.iloc[:, 0:8], inplace = True, axis = 1) 

dfd_18 = delitos_18.groupby(level=-1, axis=0).sum()

deli_18 = dfd_18.transpose()

deli_18.plot()
plt.xticks(np.arange(12), dfd_18, rotation=30)
plt.xlabel('Meses del año')
plt.ylabel('Número de delitos')

leg = plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", fontsize = 'small')

# %%
data_19 = pd.read_csv(r'C:\Users\Hp  User\Documents\Delfín\Datos\Municipios2019.csv', encoding = 'utf8')

Jalisco_19 = data_19[data_19.Entidad == 'Jalisco']

df_19 = Jalisco_19.loc[Jalisco_19['Municipio'].isin(['Guadalajara','Zapopan', "San Pedro Tlaquepaque"])]

delitos_19 = df_19.set_index(['Tipo de delito'])

delitos_19.drop(delitos_19.iloc[:, 0:8], inplace = True, axis = 1) 

dfd_19 = delitos_19.groupby(level=-1, axis=0).sum()

deli_19 = dfd_19.transpose()

deli_19.plot()
plt.xticks(np.arange(12), dfd_19, rotation=30)
plt.xlabel('Meses del año')
plt.ylabel('Número de delitos')

leg = plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", fontsize = 'small')

# %%
data_20 = pd.read_csv(r'C:\Users\Hp  User\Documents\Delfín\Datos\Municipios2020.csv', encoding = 'utf8')

Jalisco_20 = data_20[data_20.Entidad == 'Jalisco']
Jalisco_20.dropna(axis = 'columns')

df_20 = Jalisco_20.loc[Jalisco_20['Municipio'].isin(['Guadalajara','Zapopan', "San Pedro Tlaquepaque"])]

delitos_20 = df_20.set_index(['Tipo de delito'])

delitos_20.drop(delitos_20.iloc[:, 0:8], inplace = True, axis = 1) 

dfna_20 = delitos_20.dropna(axis = 'columns')
dfd_20= dfna_20.groupby(level=-1, axis=0).sum()

deli_20 = dfd_20.transpose()

deli_20.plot()
plt.xticks(np.arange(4), dfd_20, rotation=30)
plt.xlabel('Meses del año')
plt.ylabel('Número de delitos')

leg = plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", fontsize = 'small')
